# %%
# https://machinelearningmastery.com/how-to-develop-a-pix2pix-gan-for-image-to-image-translation/

# %%
# from models import define_gan

# %%
from models import *
from datagen import *
from utils import *
import os
# Out:
# Using TensorFlow backend.

# %%
# train pix2pix models
def train(d_model, g_model, gan_model, all_paths, path_labels, n_epochs=100, batch_size=1, path_results='model_performance/'):
    if not os.path.isdir(path_results):
        os.mkdir(path_results)
    
    # determine the output square shape of the discriminator
    n_patch = (d_model.output_shape[1],d_model.output_shape[2])

    bat_per_epo = int(len(all_paths)/batch_size)
    n_steps = bat_per_epo * n_epochs
    #n_steps = 5
    print('Batch per epochs = ', bat_per_epo)
    print('Total Steps = ', n_steps)
    # manually enumerate epochs
    for i in range(n_steps):
        # select a batch of real samples
        X_realA, X_realB, y_real = next(my_datagen(all_paths,path_labels, patch_shape = n_patch, batch_size=batch_size))
        # generate a batch of fake samples
        X_fakeB, y_fake = generate_fake_samples(g_model, X_realA, n_patch)
        
#         print(X_realA.shape)
#         print(X_realB.shape)
#         print(y_real.shape)
#         print('-----------')
#         print(X_fakeB.shape)
#         print(y_fake.shape)
        
        
        # update discriminator for real samples
        d_loss1 = d_model.train_on_batch([X_realA, X_realB], y_real)
        # update discriminator for generated samples
        d_loss2 = d_model.train_on_batch([X_realA, X_fakeB], y_fake)
        # update the generator
        g_loss, _, _ = gan_model.train_on_batch(X_realA, [y_real, X_realB])
        # summarize performance
        print('>%d, d1[%.3f] d2[%.3f] g[%.3f]' % (i+1, d_loss1, d_loss2, g_loss))
        # summarize model performance
        if i%bat_per_epo==0 and i>1:
            # select a sample of input images
            X_realA, X_realB, _ = next(my_datagen(all_paths, path_labels, patch_shape=n_patch, batch_size=3))
            # generate a batch of fake samples
            X_fakeB, _ = generate_fake_samples(g_model, X_realA, patch_shape=(1,1))
            summarize_performance(path_results, i, g_model,  X_realA, X_realB, X_fakeB, n_samples=3)

# %%
path_images = 'maps_dataset_subset/train_images/'
path_labels = 'maps_dataset_subset/train_maps/'

all_paths = get_paths(path_images)

image_shape = (256,256,3)

d_model, g_model, gan_model = define_gan(image_shape)

# %%
train(d_model, g_model, gan_model, all_paths, path_labels,batch_size=4)
# Out:
# Batch per epochs =  12
# Total Steps =  1200
# >1, d1[0.300] d2[1.019] g[84.720]
# >2, d1[0.304] d2[0.768] g[77.527]
# >3, d1[0.311] d2[0.591] g[80.461]
# >4, d1[0.325] d2[0.466] g[69.512]
# >5, d1[0.457] d2[0.446] g[65.270]
# >6, d1[0.343] d2[0.387] g[69.373]
# >7, d1[0.346] d2[0.370] g[63.384]
# >8, d1[0.531] d2[0.416] g[62.548]
# >9, d1[0.547] d2[0.762] g[55.499]
# >10, d1[0.594] d2[0.604] g[51.920]
# >11, d1[0.485] d2[0.344] g[52.379]
# >12, d1[0.390] d2[0.328] g[49.261]
# >13, d1[0.259] d2[0.291] g[44.398]
# >Saved: model_performance/plot_000013.png and model_performance/model.h5
# >14, d1[0.184] d2[0.271] g[46.697]
# >15, d1[0.159] d2[0.235] g[41.513]
# >16, d1[0.124] d2[0.158] g[38.173]
# >17, d1[0.151] d2[0.135] g[37.146]
# >18, d1[0.078] d2[0.170] g[44.074]
# >19, d1[0.088] d2[0.092] g[34.062]
# >20, d1[0.060] d2[0.087] g[37.061]
# >21, d1[0.091] d2[0.074] g[28.028]
# >22, d1[0.053] d2[0.076] g[31.059]
# >23, d1[0.043] d2[0.064] g[31.717]
# >24, d1[0.044] d2[0.046] g[26.464]
# >25, d1[0.044] d2[0.061] g[26.498]
# >Saved: model_performance/plot_000025.png and model_performance/model.h5
# >26, d1[0.071] d2[0.067] g[24.548]
# >27, d1[0.030] d2[0.029] g[20.419]
# >28, d1[0.057] d2[0.067] g[23.125]
# >29, d1[0.036] d2[0.027] g[18.394]
# >30, d1[0.051] d2[0.051] g[19.151]
# >31, d1[0.033] d2[0.024] g[17.726]
# >32, d1[0.026] d2[0.031] g[15.748]
# >33, d1[0.026] d2[0.028] g[17.617]
# >34, d1[0.048] d2[0.048] g[15.805]
# >35, d1[0.059] d2[0.017] g[16.118]
# >36, d1[0.021] d2[0.048] g[14.091]
# >37, d1[0.101] d2[1.483] g[15.247]
# >Saved: model_performance/plot_000037.png and model_performance/model.h5
# >38, d1[1.915] d2[0.032] g[14.678]
# >39, d1[0.908] d2[0.218] g[16.324]
# >40, d1[0.312] d2[0.397] g[12.046]
# >41, d1[0.315] d2[0.242] g[13.026]
# >42, d1[0.299] d2[0.134] g[13.119]
# >43, d1[0.301] d2[0.215] g[16.002]
# >44, d1[0.230] d2[0.084] g[12.448]
# >45, d1[0.137] d2[0.093] g[14.519]
# >46, d1[0.139] d2[0.075] g[12.167]
# >47, d1[0.044] d2[0.045] g[15.155]
# >48, d1[0.044] d2[0.041] g[11.817]
# >49, d1[0.052] d2[0.032] g[11.562]
# >Saved: model_performance/plot_000049.png and model_performance/model.h5
# >50, d1[0.036] d2[0.031] g[13.111]
# >51, d1[0.030] d2[0.026] g[13.428]
# >52, d1[0.033] d2[0.021] g[13.122]
# >53, d1[0.029] d2[0.020] g[11.604]
# >54, d1[0.020] d2[0.016] g[16.051]
# >55, d1[0.025] d2[0.014] g[14.204]
# >56, d1[0.028] d2[0.028] g[11.242]
# >57, d1[0.030] d2[0.017] g[9.873]
# >58, d1[0.013] d2[0.017] g[14.189]
# >59, d1[0.020] d2[0.019] g[11.182]
# >60, d1[0.016] d2[0.022] g[13.234]
# >61, d1[0.016] d2[0.017] g[11.129]
# >Saved: model_performance/plot_000061.png and model_performance/model.h5
# >62, d1[0.021] d2[0.010] g[11.692]
# >63, d1[0.013] d2[0.012] g[13.015]
# >64, d1[0.014] d2[0.007] g[13.007]
# >65, d1[0.012] d2[0.010] g[12.441]
# >66, d1[0.015] d2[0.010] g[10.111]
# >67, d1[0.023] d2[0.016] g[8.875]
# >68, d1[0.012] d2[0.017] g[10.122]
# >69, d1[0.011] d2[0.007] g[11.586]
# >70, d1[0.010] d2[0.007] g[11.611]
# >71, d1[0.009] d2[0.008] g[12.301]
# >72, d1[0.026] d2[0.019] g[8.214]
# >73, d1[0.008] d2[0.013] g[13.845]
# >Saved: model_performance/plot_000073.png and model_performance/model.h5
# >74, d1[0.008] d2[0.009] g[13.684]
# >75, d1[0.038] d2[0.032] g[7.793]
# >76, d1[0.019] d2[0.006] g[12.975]
# >77, d1[0.011] d2[0.011] g[12.034]
# >78, d1[0.009] d2[0.008] g[14.517]
# >79, d1[0.008] d2[0.008] g[12.095]
# >80, d1[0.010] d2[0.010] g[13.005]
# >81, d1[0.018] d2[0.011] g[8.944]
# >82, d1[0.007] d2[0.007] g[10.568]
# >83, d1[0.010] d2[0.005] g[11.896]
# >84, d1[0.026] d2[0.012] g[9.675]
# >85, d1[0.006] d2[0.008] g[11.306]
# >Saved: model_performance/plot_000085.png and model_performance/model.h5
# >86, d1[0.008] d2[0.011] g[10.995]
# >87, d1[0.007] d2[0.007] g[10.242]
# >88, d1[0.007] d2[0.006] g[9.408]
# >89, d1[0.007] d2[0.005] g[9.149]
# >90, d1[0.005] d2[0.005] g[15.038]
# >91, d1[0.009] d2[0.004] g[10.084]
# >92, d1[0.007] d2[0.007] g[12.608]
# >93, d1[0.005] d2[0.006] g[12.567]
# >94, d1[0.005] d2[0.006] g[10.545]
# >95, d1[0.006] d2[0.005] g[9.846]
# >96, d1[0.007] d2[0.004] g[17.782]
# >97, d1[0.005] d2[0.004] g[12.551]
# >Saved: model_performance/plot_000097.png and model_performance/model.h5
# >98, d1[0.005] d2[0.005] g[14.564]
# >99, d1[0.007] d2[0.005] g[11.656]
# >100, d1[0.050] d2[0.953] g[9.195]
# >101, d1[2.411] d2[0.041] g[13.232]
# >102, d1[1.189] d2[0.243] g[9.295]
# >103, d1[0.436] d2[0.380] g[11.632]
# >104, d1[0.558] d2[0.303] g[11.504]
# >105, d1[0.270] d2[0.207] g[12.529]
# >106, d1[0.225] d2[0.125] g[10.361]
# >107, d1[0.334] d2[0.105] g[9.968]
# >108, d1[0.092] d2[0.116] g[9.214]
# >109, d1[0.105] d2[0.105] g[9.972]
# >Saved: model_performance/plot_000109.png and model_performance/model.h5
# >110, d1[0.075] d2[0.232] g[15.633]
# >111, d1[0.099] d2[0.066] g[10.574]
# >112, d1[0.175] d2[0.044] g[12.661]
# >113, d1[0.231] d2[0.053] g[9.241]
# >114, d1[0.057] d2[0.045] g[9.659]
# >115, d1[0.045] d2[0.029] g[11.950]
# >116, d1[0.184] d2[0.036] g[7.954]
# >117, d1[0.036] d2[0.054] g[8.304]
# >118, d1[0.039] d2[0.032] g[9.271]
# >119, d1[0.051] d2[0.022] g[9.125]
# >120, d1[0.036] d2[0.025] g[9.121]
# >121, d1[0.034] d2[0.021] g[8.176]
# >Saved: model_performance/plot_000121.png and model_performance/model.h5
# >122, d1[0.019] d2[0.020] g[10.474]
# >123, d1[0.154] d2[0.040] g[9.376]
# >124, d1[0.022] d2[0.030] g[16.041]
# >125, d1[0.025] d2[0.023] g[10.145]
# >126, d1[0.023] d2[0.021] g[11.129]
# >127, d1[0.028] d2[0.020] g[9.768]
# >128, d1[0.026] d2[0.016] g[9.818]
# >129, d1[0.028] d2[0.018] g[8.555]
# >130, d1[0.014] d2[0.015] g[12.171]
# >131, d1[0.013] d2[0.018] g[13.345]
# >132, d1[0.017] d2[0.017] g[9.914]
# >133, d1[0.011] d2[0.020] g[10.848]
# >Saved: model_performance/plot_000133.png and model_performance/model.h5
# >134, d1[0.017] d2[0.031] g[10.217]
# >135, d1[0.014] d2[0.024] g[15.083]
# >136, d1[0.199] d2[0.097] g[9.470]
# >137, d1[0.034] d2[0.059] g[7.652]
# >138, d1[0.028] d2[0.018] g[10.726]
# >139, d1[0.024] d2[0.013] g[11.029]
# >140, d1[0.019] d2[0.015] g[11.133]
# >141, d1[0.025] d2[0.013] g[10.247]
# >142, d1[0.025] d2[0.016] g[10.047]
# >143, d1[0.011] d2[0.012] g[13.851]
# >144, d1[0.009] d2[0.013] g[11.718]
# >145, d1[0.007] d2[0.039] g[13.133]
# >Saved: model_performance/plot_000145.png and model_performance/model.h5
# >146, d1[0.083] d2[0.134] g[8.045]
# >147, d1[0.032] d2[0.036] g[11.467]
# >148, d1[0.024] d2[0.015] g[11.717]
# >149, d1[0.018] d2[0.009] g[10.710]
# >150, d1[2.185] d2[0.414] g[9.601]
# >151, d1[0.021] d2[0.029] g[15.137]
# >152, d1[0.311] d2[0.309] g[8.319]
# >153, d1[0.161] d2[0.070] g[7.808]
# >154, d1[0.063] d2[0.063] g[9.122]
# >155, d1[0.009] d2[0.028] g[10.371]
# >156, d1[0.038] d2[0.018] g[7.813]
# >157, d1[0.010] d2[0.017] g[13.327]
# >Saved: model_performance/plot_000157.png and model_performance/model.h5
# >158, d1[0.022] d2[0.020] g[11.504]
# >159, d1[0.008] d2[0.018] g[16.386]
# >160, d1[0.041] d2[0.025] g[12.167]
# >161, d1[0.012] d2[0.016] g[10.056]
# >162, d1[0.010] d2[0.016] g[14.072]
# >163, d1[0.008] d2[0.013] g[14.552]
# >164, d1[0.008] d2[0.012] g[12.730]
# >165, d1[0.025] d2[0.018] g[10.009]
# >166, d1[0.010] d2[0.013] g[9.426]
# >167, d1[0.021] d2[0.012] g[8.351]
# >168, d1[0.032] d2[0.011] g[7.461]
# >169, d1[0.018] d2[0.017] g[7.532]
# >Saved: model_performance/plot_000169.png and model_performance/model.h5
# >170, d1[0.041] d2[0.017] g[6.705]
# >171, d1[0.008] d2[0.024] g[7.683]
# >172, d1[0.005] d2[0.020] g[12.104]
# >173, d1[0.006] d2[0.012] g[13.419]
# >174, d1[0.006] d2[0.011] g[12.971]
# >175, d1[0.020] d2[0.020] g[10.553]
# >176, d1[0.004] d2[0.017] g[11.094]
# >177, d1[0.005] d2[0.008] g[11.433]
# >178, d1[0.008] d2[0.014] g[8.464]
# >179, d1[0.005] d2[0.012] g[9.857]
# >180, d1[0.070] d2[0.014] g[6.872]
# >181, d1[0.012] d2[0.030] g[10.971]
# >Saved: model_performance/plot_000181.png and model_performance/model.h5
# >182, d1[0.007] d2[0.014] g[9.957]
# >183, d1[0.009] d2[0.011] g[9.236]
# >184, d1[0.004] d2[0.008] g[16.864]
# >185, d1[0.006] d2[0.007] g[8.222]
# >186, d1[0.007] d2[0.007] g[8.620]
# >187, d1[0.010] d2[0.007] g[7.705]
# >188, d1[0.003] d2[0.007] g[11.338]
# >189, d1[0.005] d2[0.006] g[13.330]
# >190, d1[0.010] d2[0.007] g[7.987]
# >191, d1[0.007] d2[0.009] g[11.400]
# >192, d1[0.022] d2[0.006] g[7.593]
# >193, d1[0.005] d2[0.014] g[12.784]
# >Saved: model_performance/plot_000193.png and model_performance/model.h5
# >194, d1[0.004] d2[0.006] g[8.678]
# >195, d1[0.008] d2[0.008] g[8.793]
# >196, d1[0.012] d2[0.013] g[9.382]
# >197, d1[0.005] d2[0.005] g[9.211]
# >198, d1[2.054] d2[1.824] g[6.838]
# >199, d1[0.009] d2[0.060] g[10.654]
# >200, d1[0.071] d2[0.023] g[12.218]
# >201, d1[0.081] d2[0.031] g[12.539]
# >202, d1[0.334] d2[0.090] g[7.725]
# >203, d1[0.016] d2[0.372] g[10.438]
# >204, d1[0.020] d2[0.015] g[14.053]
# >205, d1[0.579] d2[0.033] g[7.824]
# >Saved: model_performance/plot_000205.png and model_performance/model.h5
# >206, d1[0.095] d2[0.278] g[9.731]
# >207, d1[0.025] d2[0.039] g[11.083]
# >208, d1[0.024] d2[0.022] g[9.122]
# >209, d1[0.028] d2[0.017] g[8.557]
# >210, d1[0.022] d2[0.012] g[12.636]
# >211, d1[0.061] d2[0.013] g[8.087]
# >212, d1[1.833] d2[0.345] g[11.163]
# >213, d1[0.020] d2[0.083] g[11.931]
# >214, d1[0.071] d2[0.068] g[8.016]
# >215, d1[0.009] d2[0.106] g[8.366]
# >216, d1[0.019] d2[0.024] g[10.789]
# >217, d1[1.431] d2[0.137] g[7.903]
# >Saved: model_performance/plot_000217.png and model_performance/model.h5
# >218, d1[0.006] d2[0.176] g[11.271]
# >219, d1[0.140] d2[0.107] g[7.352]
# >220, d1[0.012] d2[0.061] g[9.979]
# >221, d1[0.951] d2[0.217] g[5.550]
# >222, d1[0.003] d2[0.159] g[12.299]
# >223, d1[0.006] d2[0.160] g[9.801]
# >224, d1[0.010] d2[0.081] g[6.725]
# >225, d1[0.010] d2[0.026] g[10.272]
# >226, d1[0.021] d2[0.025] g[8.460]
# >227, d1[1.310] d2[0.143] g[6.138]
# >228, d1[0.004] d2[0.519] g[8.881]
# >229, d1[0.006] d2[0.043] g[9.879]
# >Saved: model_performance/plot_000229.png and model_performance/model.h5
# >230, d1[0.031] d2[0.027] g[8.483]
# >231, d1[0.015] d2[0.024] g[10.001]
# >232, d1[0.146] d2[0.040] g[7.224]
# >233, d1[0.007] d2[0.033] g[8.119]
# >234, d1[0.047] d2[0.040] g[7.138]
# >235, d1[0.097] d2[0.029] g[8.493]
# >236, d1[0.006] d2[0.049] g[10.010]
# >237, d1[0.005] d2[0.022] g[10.963]
# >238, d1[0.006] d2[0.019] g[10.050]
# >239, d1[0.006] d2[0.021] g[8.914]
# >240, d1[0.007] d2[0.019] g[11.198]
# >241, d1[0.012] d2[0.016] g[7.731]
# >Saved: model_performance/plot_000241.png and model_performance/model.h5
# >242, d1[0.006] d2[0.017] g[9.300]
# >243, d1[0.007] d2[0.060] g[11.426]
# >244, d1[0.014] d2[0.015] g[8.845]
# >245, d1[0.058] d2[0.016] g[7.193]
# >246, d1[0.007] d2[0.019] g[12.603]
# >247, d1[0.006] d2[0.012] g[11.971]
# >248, d1[0.025] d2[0.013] g[6.620]
# >249, d1[0.077] d2[0.012] g[7.025]
# >250, d1[0.006] d2[0.025] g[9.511]
# >251, d1[0.005] d2[0.032] g[11.316]
# >252, d1[0.006] d2[0.035] g[11.810]
# >253, d1[0.006] d2[0.014] g[10.749]
# >Saved: model_performance/plot_000253.png and model_performance/model.h5
# >254, d1[0.005] d2[0.021] g[14.109]
# >255, d1[0.005] d2[0.056] g[13.220]
# >256, d1[0.005] d2[0.029] g[10.363]
# >257, d1[0.044] d2[0.016] g[9.558]
# >258, d1[0.055] d2[0.059] g[10.414]
# >259, d1[0.005] d2[0.008] g[11.409]
# >260, d1[0.007] d2[0.006] g[9.823]
# >261, d1[0.011] d2[0.006] g[10.976]
# >262, d1[0.024] d2[0.008] g[8.423]
# >263, d1[0.006] d2[0.007] g[9.497]
# >264, d1[0.012] d2[0.007] g[8.150]
# >265, d1[0.007] d2[0.006] g[11.733]
# >Saved: model_performance/plot_000265.png and model_performance/model.h5
# >266, d1[0.004] d2[0.006] g[9.825]
# >267, d1[0.012] d2[0.007] g[13.204]
# >268, d1[0.003] d2[0.008] g[9.613]
# >269, d1[0.054] d2[0.008] g[7.907]
# >270, d1[0.975] d2[0.663] g[8.222]
# >271, d1[0.009] d2[0.079] g[8.769]
# >272, d1[0.072] d2[0.034] g[7.778]
# >273, d1[0.013] d2[0.018] g[10.080]
# >274, d1[0.191] d2[0.055] g[6.720]
# >275, d1[0.004] d2[0.031] g[10.524]
# >276, d1[0.005] d2[0.017] g[11.145]
# >277, d1[0.005] d2[0.042] g[9.644]
# >Saved: model_performance/plot_000277.png and model_performance/model.h5
# >278, d1[0.004] d2[0.027] g[11.455]
# >279, d1[0.010] d2[0.048] g[8.593]
# >280, d1[0.006] d2[0.011] g[8.250]
# >281, d1[0.006] d2[0.035] g[13.020]
# >282, d1[0.020] d2[0.008] g[8.712]
# >283, d1[0.005] d2[0.024] g[13.484]
# >284, d1[0.032] d2[0.075] g[9.218]
# >285, d1[0.009] d2[0.016] g[11.161]
# >286, d1[0.122] d2[0.080] g[7.555]
# >287, d1[0.024] d2[0.018] g[10.876]
# >288, d1[0.012] d2[0.049] g[10.787]
# >289, d1[0.009] d2[0.017] g[10.771]
# >Saved: model_performance/plot_000289.png and model_performance/model.h5
# >290, d1[0.849] d2[0.227] g[9.880]
# >291, d1[0.014] d2[0.159] g[7.294]
# >292, d1[0.008] d2[0.019] g[14.261]
# >293, d1[0.055] d2[0.062] g[7.391]
# >294, d1[0.008] d2[0.041] g[11.665]
# >295, d1[0.008] d2[0.012] g[11.669]
# >296, d1[0.006] d2[0.015] g[12.579]
# >297, d1[0.267] d2[0.021] g[10.420]
# >298, d1[0.005] d2[0.057] g[11.211]
# >299, d1[0.031] d2[0.010] g[7.015]
# >300, d1[0.005] d2[0.009] g[7.819]
# >301, d1[0.086] d2[0.032] g[6.309]
# >Saved: model_performance/plot_000301.png and model_performance/model.h5
# >302, d1[0.006] d2[0.015] g[11.744]
# >303, d1[0.004] d2[0.154] g[11.897]
# >304, d1[0.004] d2[0.006] g[10.029]
# >305, d1[1.089] d2[0.746] g[7.189]
# >306, d1[0.007] d2[0.040] g[12.665]
# >307, d1[0.155] d2[0.193] g[10.745]
# >308, d1[0.018] d2[0.030] g[11.362]
# >309, d1[0.017] d2[0.013] g[9.922]
# >310, d1[0.021] d2[0.014] g[8.741]
# >311, d1[0.207] d2[0.039] g[9.290]
# >312, d1[0.007] d2[0.072] g[11.773]
# >313, d1[0.006] d2[0.009] g[9.619]
# >Saved: model_performance/plot_000313.png and model_performance/model.h5
# >314, d1[0.012] d2[0.009] g[8.556]
# >315, d1[0.012] d2[0.012] g[8.884]
# >316, d1[0.014] d2[0.007] g[8.871]
# >317, d1[0.006] d2[0.006] g[11.106]
# >318, d1[0.302] d2[0.041] g[10.936]
# >319, d1[0.021] d2[0.033] g[11.428]
# >320, d1[0.003] d2[0.019] g[9.997]
# >321, d1[0.004] d2[0.018] g[13.494]
# >322, d1[0.130] d2[0.463] g[9.675]
# >323, d1[0.009] d2[0.111] g[7.390]
# >324, d1[0.023] d2[0.004] g[7.706]
# >325, d1[0.027] d2[0.007] g[10.076]
